# %% [markdown]
# <a href="https://colab.research.google.com/github/t108360107ShiQing/MachineLearning_HW3/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from glob import glob
from random import shuffle
from time import time

import numpy as np
import dill
import librosa

SENTENCE_ID = 'sentence_id'
SPEAKER_ID = 'speaker_id'
FILENAME = 'filename'

# %%
path='/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf'
for file in os.listdir(path):
  if file.endswith('.wav'):
    data=path+file
    waveoutdata=path+file
    # !sox {data} -r 16000 -e signed-integer -b 16{waveoutdata}
    print(file,"OK")
# Out:
# /bin/bash: sox: command not found
# 102.wav OK
# /bin/bash: sox: command not found
# 100.wav OK
# /bin/bash: sox: command not found
# 101.wav OK
# /bin/bash: sox: command not found
# 10.wav OK
# /bin/bash: sox: command not found
# 1.wav OK
# /bin/bash: sox: command not found
# 120.wav OK
# /bin/bash: sox: command not found
# 104.wav OK
# /bin/bash: sox: command not found
# 108.wav OK
# /bin/bash: sox: command not found
# 112.wav OK
# /bin/bash: sox: command not found
# 109.wav OK
# /bin/bash: sox: command not found
# 11.wav OK
# /bin/bash: sox: command not found
# 103.wav OK
# /bin/bash: sox: command not found
# 119.wav OK
# /bin/bash: sox: command not found
# 111.wav OK
# /bin/bash: sox: command not found
# 117.wav OK
# /bin/bash: sox: command not found
# 12.wav OK
# /bin/bash: sox: command not found
# 113.wav OK
# /bin/bash: sox: command not found
# 107.wav OK
# /bin/bash: sox: command not found
# 105.wav OK
# /bin/bash: sox: command not found
# 118.wav OK
# ...

# %%
wav16_path="/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225"
wav16_path_p225000="/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225/p225000"
wav16_path_p22500="/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225/p22500"
wav16_path_p2250="/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225/p2250"
wav16_path_p225="/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225/p225"
for file in os.listdir(wav16_path):
  if file.endswith(".wav"):
    if int(file[:-4])<10:
      filename=wav16_path+file
      new_filename=wav16_path_p225000+file
      # !mv {filename} {new_filename}
    elif int(file[:-4])<100:
      filename=wav16_path+file
      new_filename=wav16_path_p22500+file
      # !mv {filename} {new_filename}
    elif int(file[:-4])<1000:
      filename=wav16_path+file
      new_filename=wav16_path_p2250+file
      # !mv {filename} {new_filename}
    elif int(file[:-4])<1000:
      filename=wav16_path+file
      new_filename=wav16_path_p225+file
      # !mv {filename} {new_filename}

# %%
count=0
for file in os.listdir(wav16_path):
  if file.endswith(".wav"):
    with open(wav16_path+str(file[:-4])+".txt","w+")as ans:
      count+1
count
# Out:
# 0

# %%
# !cp {"/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/txt/p225/*"} {'"/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/wav16/p225/"'}
# Out:
# cp: cannot stat '/content/drive/MyDrive/Maching_Learning_HW3/ML@NTUT-2021-Autumn-ASR/test-shuf/txt/p225/*': No such file or directory

# %%
def cnter(num):
    dr=4-len(str(num))
    cnt=str('p255_'+'0'*dr+str(num)+'.wav')
    return cnt

import os
wav16="wav16/"
sourcewavpath='test/wav16/p225'
txt="txt/"
p225="p225/"
sep='test_sep/'
num=1
while num < 347:
    testfold=f'{sep}test{num}/'
    curtestfold=testfold+wav16
    if not os.path.exists(curtestfold):
        print(f"{curtestfold} not exist, create this directory")
        os.makedirs(curtestfold)
    curtestfold+=p225
    if not os.path.exists(curtestfold):
        print(f"{curtestfold} not exist, create this directory")
        os.makedirs(curtestfold)

    fname=cnter(num)[:-3]+'*'
    os.system(f'cp -v {sourcewavpath}{fname} {curtestfold}')

#--------------------------------------------------------------------------------------------
    curtestfold=testfold+txt
    if not os.path.exists(curtestfold):
        print(f"{curtestfold} not exist, create this directory")
        os.makedirs(curtestfold)
    curtestfold+=p225
    if not os.path.exists(curtestfold):
        print(f"{curtestfold} not exist, create this directory")
        os.makedirs(curtestfold)

    fname=cnter(num).replace('wav','txt')
    os.system(f'cp -v {sourcewavpath}{fname} {curtestfold}')
#--------------------------------------------------------------------------------------------
    num+=1

# %%
pip install tensorflow==2.0.0-alpha0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0-alpha0 (from versions: 1.13.1, 1.13.2, 1.14.0, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 1.15.5, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0rc0, 2.4.0rc1, 2.4.0rc2, 2.4.0rc3, 2.4.0rc4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.8.0rc0)
# ERROR: No matching distribution found for tensorflow==2.0.0-alpha0

# %%
pip install numpy==1.16.2

# %%
import tensorflow as tf
from requests.sessions import Session as sess

with tf.Session(graph=graph) as sess:

    tf.global_variables_initializer().run()
    models_name = '5000-5000'
    saver = tf.train.Saver(max_to_keep=None)

    if os.path.exists('models/checkpoint004/'):
        saver.restore(sess,'models/checkpoint004/'+models_name)

# %%
if not r'result-%s.csv'%(models_name) in os.listdir('./'):
  a=open(r'result-%s.csv'%(models_name),'w+')
  a=write('id,text\n')
  a.close

with open (r'result-%s.csv'%(models_name),mode='a') as ans:
  for jj in range(batch_size):
    value=d.values[np.where(d.indices[:,0]==jj)[0]]
    str_decoded=''.join([chr(x) for x in np.asarray(values)+FIRST_INDEX])
    str_decoded=str_decoded.replace(chr(ord('z')+1),'')
    str_decoded=str_decoded.replace(chr(ord('a')-1),'')
    print(str_decoded)
    ans.write('%s,%s\n'%(jj+snum,str_decoded))
